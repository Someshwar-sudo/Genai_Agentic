# %%
pip install langchain-google-genai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Langchain - google-genai

# %%
import os 
from langchain.chat_models import init_chat_model
os.environ['GOOGLE_API_KEY']='AIzaSyCgoTfmULv-Nnmjg3E5ZXGSfueMPiUX4a'
model=init_chat_model('google_genai:gemini-2.5-flash')
response=model.invoke('tell me differnce between genai and agentic ai').content
print(response)
# Out:
# While both Generative AI (GenAI) and Agentic AI represent advanced forms of artificial intelligence, they have fundamentally different primary goals, mechanisms, and applications.
#
# Here's a breakdown of their differences:
#
# ---
#
# ### Generative AI (GenAI)
#
# *   **Primary Goal:** To **create new, original content** (text, images, audio, video, code, etc.) that resembles data it was trained on but isn't an exact copy.
# *   **Mechanism:** It learns patterns, structures, and styles from vast datasets and then uses that understanding to **generate** novel outputs based on a given prompt or input. It's essentially a sophisticated pattern-matcher and interpolator.
# *   **Interaction Model:** Typically **prompt-in, content-out**. You give it a prompt, and it generates a single, often static, piece of content.
# *   **Key Characteristics:**
#     *   **Creativity/Novelty:** Focuses on producing unique outputs.
# ...

# %% [markdown]
# ### Langchain - google-genai with dotenv()

# %%
import os 
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
load_dotenv()
model=init_chat_model('google_genai:gemini-2.5-flash')
response=model.invoke('tell me differnce between genai and agentic ai').content
print(response)
# Out:
# While both Generative AI (GenAI) and Agentic AI represent advanced forms of artificial intelligence, they differ significantly in their primary function, how they operate, and their ultimate goals.
#
# Here's a breakdown of the key differences:
#
# ---
#
# ### Generative AI (GenAI)
#
# **What it is:** GenAI is a category of AI models designed to **create new, original content** that resembles the data they were trained on. Their core capability is synthesis and generation.
#
# **Key Characteristics:**
#
# 1.  **Primary Goal:** To generate novel outputs (text, images, audio, video, code, etc.) based on a given prompt or input.
# 2.  **Process:** Takes an input (prompt) and directly produces an output. It's often a "one-shot" generation or a series of independent generations.
# 3.  **Output:** Static content. Once generated, the output doesn't typically "do" anything further on its own.
# ...

# %%
### Message transaltor using langchain

# %%
from langchain_core.messages import HumanMessage,SystemMessage
messages=[SystemMessage('transalte the sentences in telugu'),
         HumanMessage('Hi How are you')]
model=init_chat_model('google_genai:gemini-2.5-flash')
response=model.invoke(messages).content
print(response)
# Out:
# **నమస్కారం, మీరు ఎలా ఉన్నారు?**
#
# (Namaskaram, meeru elaa unnaaru?)
#
# You could also say:
#
# *   **హాయ్, ఎలా ఉన్నారు?** (Hai, elaa unnaaru?) - (More informal, using "Hi" directly)
# *   **నువ్వు ఎలా ఉన్నావు?** (Nuvvu elaa unnaavu?) - (If speaking to someone you know well and can address informally)

# %%
# Out:
# 2026-06-06 15:57:37.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-06 15:57:37.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-06 15:57:37.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-06 15:57:37.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-06 15:57:37.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-06 15:57:37.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-06 15:57:37.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
dir(st)
# Out:
# ['Page',
#  '_ContextProxy',
#  '_DeltaGenerator',
#  '_DeltaGeneratorSingleton',
#  '_Dialog',
#  '_ExpanderContainer',
#  '_PopoverContainer',
#  '_QueryParamsProxy',
#  '_STREAMLIT_VERSION_STRING',
#  '_SessionStateProxy',
#  '_StatusContainer',
#  '_TabContainer',
#  '_UserInfoProxy',
#  '__annotations__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_bidi_component',
#  '_bottom',
#  '_cache',
#  '_cache_data',
#  '_cache_resource',
#  '_column_config',
#  '_config',
#  '_connection',
#  '_dg_singleton',
#  '_dialog_decorator',
#  '_event',
#  '_fragment',
#  '_gather_metrics',
#  '_logger',
#  '_login',
#  '_logout',
#  '_main',
#  '_os',
#  '_secrets_singleton',
#  '_update_logger',
#  'altair_chart',
#  'area_chart',
#  'audio',
#  'audio_input',
#  'auth_util',
#  'badge',
#  'balloons',
#  'bar_chart',
#  'bokeh_chart',
#  'button',
#  'cache',
# ...
